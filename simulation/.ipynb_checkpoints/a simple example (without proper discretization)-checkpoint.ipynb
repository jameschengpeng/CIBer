# %% [markdown]
# We assume there are only two predictors $X_0$ and $X_1$. Points in class $0$ fall on the line segment $X_1 = X_0 + 20$ with $X_0 \in [0,100]$. Points in class $1$ fall on the line segment $X_1 = X_0 - 20$ with $X_0 \in [20,120]$. Please note that in both cases $X_0$ are uniformly distributed. We assume $X_0$ and $X_1$ are comonotonic. In this notebook, we compare CIBer with Naive Bayes.
# Let's first think of an example. If we would like to classify point $(55,35)$. We know that it should be class $1$ since it falls on the line segment $X_1 = X_0 - 20$. Furtherly, suppose we discretize $X_0$ into equal bins with length $10$. Then each conditional marginal probability equals to $0.1$.
#
# $\textbf{Naive Bayes}$
#
# $\mathbb{P}(X_0,X_1|Y=0)\cdot \mathbb{P}(Y=0)=0.1\cdot0.1\cdot0.5=0.0005$
#
# $\mathbb{P}(X_0,X_1|Y=1)\cdot \mathbb{P}(Y=1)=0.1\cdot0.1\cdot0.5=0.0005$
#
# $\textbf{CIBer}$
#
# $\mathbb{P}(X_0,X_1|Y=0)\cdot \mathbb{P}(Y=0)= Leb([0.5,0.6]\cap[0.1,0.2])\cdot0.5=0$
#
# $\mathbb{P}(X_0,X_1|Y=1)\cdot \mathbb{P}(Y=1)= Leb([0.3,0.4]\cap[0.3,0.4])\cdot0.5=0.05$
#
# So we can see that Naive Bayes can not make a decision but CIBer will definitely predict it as class $1$.

# %%
import numpy as np
import pandas as pd
import sys
sys.path.insert(1, '/home/r7user5/Desktop/STAT')
import comonotonic as cm
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import utils
from sklearn import preprocessing
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, roc_auc_score
from multiprocessing import Pool
import time
import xlsxwriter
import copy
import math
import statistics

# %%
# here n_features stands for the pairs of features!!!
def experiment(bin_num, n_features):
    n_sample_each_class = 50000
    data0 = list()
    data1 = list()
    for i in range(n_features):
        underlying0 = np.random.uniform(0,100,n_sample_each_class)
        derivative0 = underlying0 + 20
        data0.append(underlying0)
        data0.append(derivative0)

        underlying1 = np.random.uniform(20,120,n_sample_each_class)
        derivative1 = underlying1 - 20
        data1.append(underlying1)
        data1.append(derivative1)
    data0 = np.array(data0).T
    data1 = np.array(data1).T
    
    class0 = np.array([0 for i in range(n_sample_each_class)]).reshape(-1,1)
    class1 = np.array([1 for i in range(n_sample_each_class)]).reshape(-1,1)
    class0 = np.concatenate((data0, class0), axis = 1)
    class1 = np.concatenate((data1, class1), axis = 1)
    data = np.concatenate((class0, class1), axis = 0)
    X = data[:,:-1]
    Y = data[:,-1]
    cont_col = [i for i in range(X.shape[1])]
    categorical = []
    discrete_feature_val = None
    allocation_book = {i:bin_num for i in cont_col}
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,shuffle = True)
    
    time1 = time.time()
    ciber = cm.clustered_comonotonic(X_train,Y_train,discrete_feature_val,cont_col,categorical,
                                     0.6,None,corrtype = 'mutual_info',discrete_method = "custom",
                                     allocation_book = allocation_book)
    ciber.run()
    time2 = time.time()
    discretized_x_test = ciber.discretize_test(X_test)
    time3 = time.time()
    ciber_predict = ciber.predict(discretized_x_test)
    time4 = time.time()
    ciber_train = time2 - time1
    ciber_test = time4 - time3
    
    time5 = time.time()
    ciber_nb = cm.clustered_comonotonic(X_train,Y_train,discrete_feature_val,cont_col,categorical,
                                        1,None,corrtype = 'mutual_info',discrete_method = "custom",
                                        allocation_book = allocation_book)
    ciber_nb.run()
    time6 = time.time()
    
    time7 = time.time()
    ciber_nb_predict = ciber_nb.predict(discretized_x_test)
    time8 = time.time()
    nb_train = time6 - time5
    nb_test = time8 - time7
    
    return ciber_train, ciber_test, nb_train, nb_test

# %%
def repeat_experiment(bin_num, n_features, n_repeat):
    ciber_train_time = []
    ciber_test_time = []
    nb_train_time = []
    nb_test_time = []
    params = [(bin_num,n_features) for i in range(n_repeat)]
    pool = Pool()
    results = pool.starmap(experiment, params)
    pool.close()
    for result in results:
        ciber_train_time.append(result[0])
        ciber_test_time.append(result[1])
        nb_train_time.append(result[2])
        nb_test_time.append(result[3])
    return ciber_train_time, ciber_test_time, nb_train_time, nb_test_time

# %%
bin_num = 100
features = [i+2 for i in range(48)]
n_repeat = 10
c_train = dict()
c_test = dict()
n_train = dict()
n_test = dict()
for n_features in features:
    a,b,c,d = repeat_experiment(bin_num, n_features, n_repeat)
    c_train[n_features*2] = a.copy()
    c_test[n_features*2] = b.copy()
    n_train[n_features*2] = c.copy()
    n_test[n_features*2] = d.copy()
    del a,b,c,d
# Out:
# Process ForkPoolWorker-375:
# Process ForkPoolWorker-381:
# Process ForkPoolWorker-363:
# Process ForkPoolWorker-343:
# Process ForkPoolWorker-340:
# Process ForkPoolWorker-364:
# Process ForkPoolWorker-352:
# Process ForkPoolWorker-356:
# Process ForkPoolWorker-373:
# Process ForkPoolWorker-355:
# Process ForkPoolWorker-347:
# Process ForkPoolWorker-333:
# Process ForkPoolWorker-335:
# Process ForkPoolWorker-368:
# Process ForkPoolWorker-365:
# Process ForkPoolWorker-374:
# Process ForkPoolWorker-376:
# Process ForkPoolWorker-360:
# Process ForkPoolWorker-377:
# Process ForkPoolWorker-367:
# Process ForkPoolWorker-379:
# Process ForkPoolWorker-346:
# Process ForkPoolWorker-349:
# Process ForkPoolWorker-338:
# Process ForkPoolWorker-369:
# Process ForkPoolWorker-336:
# Process ForkPoolWorker-353:
# Process ForkPoolWorker-350:
# Process ForkPoolWorker-334:
# Process ForkPoolWorker-384:
# Process ForkPoolWorker-358:
# Process ForkPoolWorker-361:
# Process ForkPoolWorker-337:
# Process ForkPoolWorker-371:
# Process ForkPoolWorker-351:
# Process ForkPoolWorker-378:
# Process ForkPoolWorker-331:
# Process ForkPoolWorker-345:
# Traceback (most recent call last):
# Process ForkPoolWorker-380:
# Process ForkPoolWorker-362:
# Process ForkPoolWorker-354:
# Process ForkPoolWorker-366:
# Process ForkPoolWorker-359:
# Process ForkPoolWorker-332:
# Process ForkPoolWorker-370:
# Process ForkPoolWorker-344:
# Process ForkPoolWorker-357:
# Process ForkPoolWorker-342:
# Process ForkPoolWorker-382:
# Process ForkPoolWorker-339:
# Process ForkPoolWorker-372:
# Process ForkPoolWorker-383:
# Process ForkPoolWorker-348:
# Process ForkPoolWorker-341:
# Process ForkPoolWorker-322:
# Process ForkPoolWorker-324:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-323:
# Process ForkPoolWorker-328:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-330:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-325:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-326:
# Process ForkPoolWorker-321:
# Process ForkPoolWorker-329:
# Process ForkPoolWorker-327:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 323, in issubclass_
#     return issubclass(arg1, arg2)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 323, in issubclass_
#     return issubclass(arg1, arg2)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: issubclass() arg 1 must be a class
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# TypeError: issubclass() arg 1 must be a class
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
# KeyboardInterrupt
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
# KeyboardInterrupt
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<__array_function__ internals>", line 6, in digitize
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in digitize
#   File "<__array_function__ internals>", line 6, in digitize
#   File "<__array_function__ internals>", line 6, in digitize
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4770, in digitize
#     bins = _nx.asarray(bins)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<__array_function__ internals>", line 6, in digitize
#   File "<__array_function__ internals>", line 6, in digitize
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4773, in digitize
#     if np.issubdtype(x.dtype, _nx.complexfloating):
#   File "<__array_function__ internals>", line 4, in digitize
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4770, in digitize
#     bins = _nx.asarray(bins)
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4776, in digitize
#     mono = _monotonicity(bins)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4773, in digitize
#     if np.issubdtype(x.dtype, _nx.complexfloating):
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4786, in digitize
#     return _nx.searchsorted(bins, x, side=side)
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/multiprocessing/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 387, in issubdtype
#     if not issubclass_(arg1, generic):
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 389, in issubdtype
#     if not issubclass_(arg2, generic):
#   File "<ipython-input-2-7613d195b0be>", line 38, in experiment
#     discretized_x_test = ciber.discretize_test(X_test)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py", line 83, in asarray
#     return array(a, dtype, copy=False, order=order)
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 323, in issubclass_
#     return issubclass(arg1, arg2)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 4, in searchsorted
# KeyboardInterrupt
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
#   File "/home/r7user5/Desktop/STAT/comonotonic.py", line 346, in discretize_test
#     cate_x.append(np.digitize(f,self.bin_info[i]))
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 1272, in _searchsorted_dispatcher
#     def _searchsorted_dispatcher(a, v, side=None, sorter=None):
#   File "<__array_function__ internals>", line 6, in digitize
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in digitize
# KeyboardInterrupt
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4773, in digitize
#     if np.issubdtype(x.dtype, _nx.complexfloating):
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py", line 4773, in digitize
#     if np.issubdtype(x.dtype, _nx.complexfloating):
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 387, in issubdtype
#     if not issubclass_(arg1, generic):
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 387, in issubdtype
#     if not issubclass_(arg1, generic):
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 323, in issubclass_
#     return issubclass(arg1, arg2)
#   File "/home/r7user5/anaconda3/lib/python3.7/site-packages/numpy/core/numerictypes.py", line 324, in issubclass_
#     except TypeError:
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-fa5293b60421> in <module>
#       7 n_test = dict()
#       8 for n_features in features:
# ----> 9     a,b,c,d = repeat_experiment(bin_num, n_features, n_repeat)
#      10     c_train[n_features*2] = a.copy()
#      11     c_test[n_features*2] = b.copy()
#
# <ipython-input-3-fdf5fcfd5d8a> in repeat_experiment(bin_num, n_features, n_repeat)
#       6     params = [(bin_num,n_features) for i in range(n_repeat)]
#       7     pool = Pool()
# ----> 8     results = pool.starmap(experiment, params)
#       9     pool.close()
#      10     for result in results:
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     274         `func` and (a, b) becomes func(a, b).
#     275         '''
# --> 276         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     277
#     278     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
def compute_CI(ll):
    mean = statistics.mean(ll)
    std = statistics.stdev(ll)
    t_value = 2.2622
    lower = mean - t_value * std / math.sqrt(9)
    upper = mean + t_value * std / math.sqrt(9)
    return mean, lower, upper

# %%
workbook1 = xlsxwriter.Workbook('c_train.xlsx')
workbook2 = xlsxwriter.Workbook('c_test.xlsx')
workbook3 = xlsxwriter.Workbook('n_train.xlsx')
workbook4 = xlsxwriter.Workbook('n_test.xlsx')
worksheet1 = workbook1.add_worksheet()
worksheet2 = workbook2.add_worksheet()
worksheet3 = workbook3.add_worksheet()
worksheet4 = workbook4.add_worksheet()

title = ['n_feature','mean','T lower','T upper'] + ["time "+str(i+1) for i in range(n_repeat)]
for i,t in enumerate(title):
    worksheet1.write(0, i, t)
    worksheet2.write(0, i, t)
    worksheet3.write(0, i, t)
    worksheet4.write(0, i, t)

row = 1
for f in c_train.keys():
    worksheet1.write(row, 0, f)
    m1, l1, u1 = compute_CI(c_train[f])
    worksheet1.write(row, 1, m1)
    worksheet1.write(row, 2, l1)
    worksheet1.write(row, 3, u1)
    for i, t in enumerate(c_train[f]):
        worksheet1.write(row, i+4, t)
    
    worksheet2.write(row, 0, f)
    m2, l2, u2 = compute_CI(c_test[f])
    worksheet2.write(row, 1, m2)
    worksheet2.write(row, 2, l2)
    worksheet2.write(row, 3, u2)
    for i, t in enumerate(c_test[f]):
        worksheet2.write(row, i+4, t)

    worksheet3.write(row, 0, f)
    m3, l3, u3 = compute_CI(n_train[f])
    worksheet3.write(row, 1, m3)
    worksheet3.write(row, 2, l3)
    worksheet3.write(row, 3, u3)
    for i, t in enumerate(n_train[f]):
        worksheet3.write(row, i+4, t)

    worksheet4.write(row, 0, f)
    m4, l4, u4 = compute_CI(n_test[f])
    worksheet4.write(row, 1, m4)
    worksheet4.write(row, 2, l4)
    worksheet4.write(row, 3, u4)
    for i, t in enumerate(n_test[f]):
        worksheet4.write(row, i+4, t)
    
    row += 1

workbook1.close()
workbook2.close()
workbook3.close()
workbook4.close()

# %%
fig = plt.figure()
fig.suptitle('Running Time', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(data_to_plot)

ax.set_xlabel('Methods')
ax.set_ylabel('Time')
ax.set_xticklabels(['CIBer Train','CIBer Test' ,'NB Train', 'NB Test'])

plt.savefig('time comparison.png', format='png', dpi=1200)
plt.show()
